# %%
# !pip install mcp
# Out:
# Collecting mcp
#   Downloading mcp-1.13.1-py3-none-any.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: anyio>=4.5 in /Users/krishna/.local/lib/python3.10/site-packages (from mcp) (4.6.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from mcp) (2.10.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from mcp) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from mcp) (0.0.20)
# Collecting pydantic<3.0.0,>=2.11.0
#   Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Collecting sse-starlette>=1.6.1
#   Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from mcp) (0.35.0)
# Requirement already satisfied: httpx>=0.27.1 in /Users/krishna/.local/lib/python3.10/site-packages (from mcp) (0.27.2)
# Requirement already satisfied: starlette>=0.27 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from mcp) (0.47.3)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from mcp) (0.4.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/krishna/.local/lib/python3.10/site-packages (from anyio>=4.5->mcp) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/krishna/.local/lib/python3.10/site-packages (from anyio>=4.5->mcp) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.1 in /Users/krishna/.local/lib/python3.10/site-packages (from anyio>=4.5->mcp) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from anyio>=4.5->mcp) (3.4)
# Requirement already satisfied: httpcore==1.* in /Users/krishna/.local/lib/python3.10/site-packages (from httpx>=0.27.1->mcp) (1.0.5)
# Requirement already satisfied: certifi in /Users/krishna/miniforge3/lib/python3.10/site-packages (from httpx>=0.27.1->mcp) (2025.8.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/krishna/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp) (0.14.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp) (0.27.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp) (25.3.0)
# Requirement already satisfied: referencing>=0.28.4 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp) (0.36.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp) (2025.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.11.0->mcp) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.11.0->mcp) (0.4.1)
# Collecting pydantic-core==2.33.2
#   Using cached pydantic_core-2.33.2-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/krishna/miniforge3/lib/python3.10/site-packages (from pydantic-settings>=2.5.2->mcp) (1.0.1)
# Collecting anyio>=4.5
#   Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 843.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: click>=7.0 in /Users/krishna/.local/lib/python3.10/site-packages (from uvicorn>=0.31.1->mcp) (8.1.7)
# Installing collected packages: pydantic-core, anyio, sse-starlette, pydantic, mcp
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.6.0
#     Uninstalling anyio-4.6.0:
#       Successfully uninstalled anyio-4.6.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# classiq 0.54.0 requires numpy<2.0.0,>=1.20.1; python_version < "3.12", but you have numpy 2.1.3 which is incompatible.
# Successfully installed anyio-4.10.0 mcp-1.13.1 pydantic-2.11.7 pydantic-core-2.33.2 sse-starlette-3.0.2

# %%
import arxiv
import json
import os
from typing import List
from mcp.server.fastmcp import FastMCP

# %%
PAPER_DIR = 'Papers'

# initialize FastMCP server
mcp = FastMCP("research")

@mcp.tool()
def search_paper(topic : str, max_results : int = 5)->List[str]:
    """
    Search for papers on arXiv based on a topic and store their information.
    
    Args:
        topic: The topic to search for
        max_results: Maximum number of results to retrieve (default: 5)
        
    Returns:
        List of paper IDs found in the search
    """

    # use arxiv to find papers
    client = arxiv.Client()

    # search for most relevant articles
    search = arxiv.Search(
        query = topic,
        max_results = max_results,
        sort_by = arxiv.SortCriterion.Relevance
    )

    papers = client.results(search)

    # Create directory for this topic
    path = os.path.join(PAPER_DIR, topic.lower().replace(" ", "_"))
    os.makedirs(path, exist_ok=True)
    
    file_path = os.path.join(path, "papers_info.json")

    # Try to load existing papers info
    try:
        with open(file_path, "r") as json_file:
            papers_info = json.load(json_file)
    except (FileNotFoundError, json.JSONDecodeError):
        papers_info = {}

    # Process each paper and add to papers_info  
    paper_ids = []
    for paper in papers:
        paper_ids.append(paper.get_short_id())
        paper_info = {
            'title': paper.title,
            'authors': [author.name for author in paper.authors],
            'summary': paper.summary,
            'pdf_url': paper.pdf_url,
            'published': str(paper.published.date())
        }
        papers_info[paper.get_short_id()] = paper_info
    
    # Save updated papers_info to json file
    with open(file_path, "w") as json_file:
        json.dump(papers_info, json_file, indent=2)
    
    print(f"Results are saved in: {file_path}")
    
    return paper_ids

# %%
@mcp.tool()
def extract_info(paper_id: str) -> str:
    """
    Search for information about a specific paper across all topic directories.
    
    Args:
        paper_id: The ID of the paper to look for
        
    Returns:
        JSON string with paper information if found, error message if not found
    """
 
    for item in os.listdir(PAPER_DIR):
        item_path = os.path.join(PAPER_DIR, item)
        if os.path.isdir(item_path):
            file_path = os.path.join(item_path, "papers_info.json")
            if os.path.isfile(file_path):
                try:
                    with open(file_path, "r") as json_file:
                        papers_info = json.load(json_file)
                        if paper_id in papers_info:
                            return json.dumps(papers_info[paper_id], indent=2)
                except (FileNotFoundError, json.JSONDecodeError) as e:
                    print(f"Error reading {file_path}: {str(e)}")
                    continue
    
    return f"There's no saved information related to paper {paper_id}."



if __name__ == "__main__":
    # Initialize and run the server
    mcp.run(transport='stdio')
